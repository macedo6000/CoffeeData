# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from path import Path
import matplotlib.pyplot as plt

# %%
# import file_path and make dataframe

commodity_file_path = Path('./data/psd_coffee.csv')
commodity_df = pd.read_csv(commodity_file_path, index_col=0)
commodity_df.head()
# Out:
#                Commodity_Description Country_Code Country_Name  Market_Year  \
# Commodity_Code
# 711100                 Coffee, Green           AG      Algeria         2003
# 711100                 Coffee, Green           AG      Algeria         2003
# 711100                 Coffee, Green           AG      Algeria         2003
# 711100                 Coffee, Green           AG      Algeria         2003
# 711100                 Coffee, Green           AG      Algeria         2003
#
#                 Calendar_Year  Month  Attribute_ID Attribute_Description  \
# Commodity_Code
# 711100                   2012      6            29    Arabica Production
# 711100                   2012      6            90          Bean Exports
# 711100                   2012      6            58          Bean Imports
# 711100                   2012      6            20      Beginning Stocks
# 711100                   2012      6           125  Domestic Consumption
#
#                 Unit_ID   Unit_Description   Value
# Commodity_Code
# 711100                2  (1000 60 KG BAGS)     0.0
# 711100                2  (1000 60 KG BAGS)     0.0
# 711100                2  (1000 60 KG BAGS)  1800.0
# 711100                2  (1000 60 KG BAGS)     0.0
# 711100                2  (1000 60 KG BAGS)  1805.0

# %%
# print dataframe columns

commodity_df.columns
# Out:
# Index(['Commodity_Description', 'Country_Code', 'Country_Name', 'Market_Year',
#        'Calendar_Year', 'Month', 'Attribute_ID', 'Attribute_Description',
#        'Unit_ID', 'Unit_Description', 'Value'],
#       dtype='object')

# %%
# Check for blanks 
commodity_df.isna().sum()
# Out:
# Commodity_Description    0
# Country_Code             0
# Country_Name             0
# Market_Year              0
# Calendar_Year            0
# Month                    0
# Attribute_ID             0
# Attribute_Description    0
# Unit_ID                  0
# Unit_Description         0
# Value                    0
# dtype: int64

# %%
#  Check for duplicates
commodity_df.duplicated().sum()
# Out:
# 0

# %%
# Drop NaNs and check isna() again
commodity_df.dropna()
commodity_df.isna().sum()
# Out:
# Commodity_Description    0
# Country_Code             0
# Country_Name             0
# Market_Year              0
# Calendar_Year            0
# Month                    0
# Attribute_ID             0
# Attribute_Description    0
# Unit_ID                  0
# Unit_Description         0
# Value                    0
# dtype: int64

# %%
# get row count and datatype info on community df
commodity_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77957 entries, 711100 to 711100
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Commodity_Description  77957 non-null  object
#  1   Country_Code           77957 non-null  object
#  2   Country_Name           77957 non-null  object
#  3   Market_Year            77957 non-null  int64
#  4   Calendar_Year          77957 non-null  int64
#  5   Month                  77957 non-null  int64
#  6   Attribute_ID           77957 non-null  int64
#  7   Attribute_Description  77957 non-null  object
#  8   Unit_ID                77957 non-null  int64
#  9   Unit_Description       77957 non-null  object
#  10  Value                  77957 non-null  float64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 7.1+ MB

# %%
# Note the 'Value' column has many Zeros, check to see the number of zeros in this column
value_zero = commodity_df['Value'] == 0
value_nonzero = commodity_df['Value'] > 0

count_zero = len(commodity_df.loc[value_zero])
count_nonzero = len(commodity_df.loc[value_nonzero])

print(f'Count of zero Values: {count_zero}')
print(f'Count of non-zero Values: {count_nonzero}')
# Out:
# Count of zero Values: 36431
# Count of non-zero Values: 41526

# %%
# consolidate commodity_df into only non_zeros for 'Value' column
nonzero_df = commodity_df.loc[value_nonzero]
nonzero_df.head()
# Out:
#                Commodity_Description Country_Code Country_Name  Market_Year  \
# Commodity_Code
# 711100                 Coffee, Green           AG      Algeria         2003
# 711100                 Coffee, Green           AG      Algeria         2003
# 711100                 Coffee, Green           AG      Algeria         2003
# 711100                 Coffee, Green           AG      Algeria         2003
# 711100                 Coffee, Green           AG      Algeria         2003
#
#                 Calendar_Year  Month  Attribute_ID   Attribute_Description  \
# Commodity_Code
# 711100                   2012      6            58            Bean Imports
# 711100                   2012      6           125    Domestic Consumption
# 711100                   2012      6            57                 Imports
# 711100                   2012      6           141  Rst,Ground Dom. Consum
# 711100                   2012      6           154      Soluble Dom. Cons.
#
#                 Unit_ID   Unit_Description   Value
# Commodity_Code
# 711100                2  (1000 60 KG BAGS)  1800.0
# 711100                2  (1000 60 KG BAGS)  1805.0
# 711100                2  (1000 60 KG BAGS)  1805.0
# 711100                2  (1000 60 KG BAGS)  1800.0
# 711100                2  (1000 60 KG BAGS)     5.0

# %%
nonzero_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41526 entries, 711100 to 711100
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Commodity_Description  41526 non-null  object
#  1   Country_Code           41526 non-null  object
#  2   Country_Name           41526 non-null  object
#  3   Market_Year            41526 non-null  int64
#  4   Calendar_Year          41526 non-null  int64
#  5   Month                  41526 non-null  int64
#  6   Attribute_ID           41526 non-null  int64
#  7   Attribute_Description  41526 non-null  object
#  8   Unit_ID                41526 non-null  int64
#  9   Unit_Description       41526 non-null  object
#  10  Value                  41526 non-null  float64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 3.8+ MB

# %%
# define get_unique_values_df function to make a dataframe of each column and its unique values
def get_unique_values_df(df):

    # initialize unique_dict and unique_values_list
    unique_values_list = []

    # copy dataframe
    df = df.copy()

    # iterate through columns
    for column in df.columns:
        # extract unique values
        unique_values = df[column].unique()
        # append unique values from each column to unique_values_list
        unique_values_list.append(unique_values)

    # make a dataframe of column name and unique values 
    values_df = pd.DataFrame({'Column Name':[col for col in df.columns], 'Unique_Values': unique_values_list, 'Unique_Count': [len(item) for item in unique_values_list]}) 

    # return dataframe
    return values_df

# %%
unique_values_df = get_unique_values_df(nonzero_df)
unique_values_df.head(11)
# Out:
#               Column Name                                      Unique_Values  \
# 0   Commodity_Description                                    [Coffee, Green]
# 1            Country_Code  [AG, AO, AR, AS, DM, BL, BR, BY, CM, CA, CT, C...
# 2            Country_Name  [Algeria, Angola, Argentina, Australia, Benin,...
# 3             Market_Year  [2003, 2004, 2005, 2006, 2007, 2008, 2009, 201...
# 4           Calendar_Year  [2012, 2015, 2014, 2016, 2017, 2018, 2020, 202...
# 5                   Month                                         [6, 12, 0]
# 6            Attribute_ID  [58, 125, 57, 141, 154, 82, 178, 86, 29, 90, 2...
# 7   Attribute_Description  [Bean Imports, Domestic Consumption, Imports, ...
# 8                 Unit_ID                                                [2]
# 9        Unit_Description                                [(1000 60 KG BAGS)]
# 10                  Value  [1800.0, 1805.0, 5.0, 1960.0, 1970.0, 10.0, 19...
#
#     Unique_Count
# 0              1
# 1             84
# 2             84
# 3             64
# 4             62
# 5              3
# 6             19
# 7             19
# 8              1
# 9              1
# 10          4355

# %%
# define function to get unique values from input column
def get_unique_values(member):
    # extract unique values from input column
    unique_values = list(member.unique())
    # print the number of unique values
    print(len(unique_values))
    # print unique values
    print(unique_values)

    #return unique values
    return unique_values

# %%
country_unique = get_unique_values(nonzero_df['Country_Name'])
# Out:
# 84
# ['Algeria', 'Angola', 'Argentina', 'Australia', 'Benin', 'Bolivia', 'Brazil', 'Burundi', 'Cameroon', 'Canada', 'Central African Republic', 'Chile', 'China', 'Colombia', 'Congo (Brazzaville)', 'Congo (Kinshasa)', 'Costa Rica', "Cote d'Ivoire", 'Cuba', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Equatorial Guinea', 'Ethiopia', 'European Union', 'Gabon', 'Ghana', 'Guatemala', 'Guinea', 'Guyana', 'Haiti', 'Honduras', 'India', 'Indonesia', 'Iran', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Korea, South', 'Laos', 'Liberia', 'Madagascar', 'Malawi', 'Malaysia', 'Mexico', 'Morocco', 'New Caledonia', 'New Zealand', 'Nicaragua', 'Nigeria', 'Norway', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Russia', 'Rwanda', 'Saudi Arabia', 'Serbia', 'Sierra Leone', 'Singapore', 'South Africa', 'Sri Lanka', 'Switzerland', 'Taiwan', 'Tanzania', 'Thailand', 'Togo', 'Trinidad and Tobago', 'Turkey', 'Uganda', 'Ukraine', 'United Kingdom', 'United States', 'Venezuela', 'Vietnam', 'Yemen', 'Yemen (Sanaa)', 'Zambia', 'Zimbabwe']

# %%
month_unique = get_unique_values(nonzero_df['Month'])
# Out:
# 3
# [6, 12, 0]

# %%
attribute_description_unique = get_unique_values(nonzero_df['Attribute_Description'])
# Out:
# 19
# ['Bean Imports', 'Domestic Consumption', 'Imports', 'Rst,Ground Dom. Consum', 'Soluble Dom. Cons.', 'Soluble Imports', 'Total Distribution', 'Total Supply', 'Arabica Production', 'Bean Exports', 'Beginning Stocks', 'Ending Stocks', 'Exports', 'Production', 'Robusta Production', 'Roast & Ground Imports', 'Roast & Ground Exports', 'Soluble Exports', 'Other Production']

# %%
market_year_unique = get_unique_values(nonzero_df['Market_Year'])
# Out:
# 64
# [2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 1960]

# %%
calendar_year_unique = get_unique_values(nonzero_df['Calendar_Year'])
# Out:
# 62
# [2012, 2015, 2014, 2016, 2017, 2018, 2020, 2021, 2022, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2010, 2011, 2019, 2006, 2013, 2007, 2008, 2009, 1959]

# %%
country_labels = country_unique
country_values = nonzero_df['Value'].groupby(nonzero_df['Country_Name']).sum()

# %%
plt.subplots(figsize=(10,14))
country_values.plot.barh('Country_Name','Value')
# Out:
# <AxesSubplot: ylabel='Country_Name'>

# %%
attribute_values_country = nonzero_df.groupby(['Attribute_Description','Country_Name'])['Value'].sum().unstack()
attribute_values_country
# Out:
# Country_Name            Algeria    Angola  Argentina  Australia  Benin  \
# Attribute_Description
# Arabica Production          NaN    1310.0        NaN        NaN    NaN
# Bean Exports                NaN   53674.0        NaN        NaN  836.0
# Bean Imports            43325.0       NaN    10149.0    25160.0    NaN
# Beginning Stocks            NaN   78552.0        NaN        NaN   44.0
# Domestic Consumption    43940.0    2950.0    15604.0    33105.0   33.0
# Ending Stocks               NaN   77735.0        NaN        NaN   44.0
# Exports                     NaN   53674.0        NaN        NaN  836.0
# Imports                 43940.0       NaN    15604.0    33105.0    NaN
# Other Production            NaN       NaN        NaN        NaN    NaN
# Production                  NaN   55807.0        NaN        NaN  869.0
# Roast & Ground Exports      NaN       NaN        NaN        NaN    NaN
# Roast & Ground Imports      NaN       NaN      280.0     2735.0    NaN
# Robusta Production          NaN   54497.0        NaN        NaN  869.0
# Rst,Ground Dom. Consum  43335.0    2950.0    10459.0    27865.0   33.0
# Soluble Dom. Cons.        605.0       NaN     5145.0     5240.0    NaN
# Soluble Exports             NaN       NaN        NaN        NaN    NaN
# Soluble Imports           615.0       NaN     5175.0     5210.0    NaN
# Total Distribution      43940.0  134359.0    15604.0    33105.0  913.0
# Total Supply            43940.0  134359.0    15604.0    33105.0  913.0
#
# Country_Name            Bolivia     Brazil  Burundi  Cameroon   Canada  ...  \
# Attribute_Description                                                   ...
# Arabica Production       7257.0  1764750.0  21403.0   12677.0      NaN  ...
# Bean Exports             4554.0  1275801.0  21797.0   63932.0      NaN  ...
# Bean Imports                NaN       16.0      NaN      80.0  50725.0  ...
# Beginning Stocks         3795.0  1293742.0   6959.0   22049.0      NaN  ...
# Domestic Consumption     2708.0   788931.0    179.0    3232.0  86935.0  ...
# Ending Stocks            3790.0  1244342.0   6959.0   22032.0      NaN  ...
# Exports                  4554.0  1415966.0  21797.0   64254.0      NaN  ...
# Imports                     NaN      647.0      NaN     168.0  86935.0  ...
# Other Production            NaN        NaN      NaN       NaN      NaN  ...
# Production               7257.0  2154850.0  21976.0   67301.0      NaN  ...
# Roast & Ground Exports      NaN     1753.0      NaN     322.0      NaN  ...
# Roast & Ground Imports      NaN      631.0      NaN       6.0  13395.0  ...
# Robusta Production          NaN   390100.0    573.0   54624.0      NaN  ...
# Rst,Ground Dom. Consum   2708.0   757712.0    179.0    2964.0  64120.0  ...
# Soluble Dom. Cons.          NaN    31219.0      NaN     268.0  22815.0  ...
# Soluble Exports             NaN   138412.0      NaN       NaN      NaN  ...
# Soluble Imports             NaN        NaN      NaN      82.0  22815.0  ...
# Total Distribution      11052.0  3449239.0  28935.0   89518.0  86935.0  ...
# Total Supply            11052.0  3449239.0  28935.0   89518.0  86935.0  ...
#
# Country_Name              Uganda  Ukraine  United Kingdom  United States  \
# Attribute_Description
# Arabica Production       26928.0      NaN             NaN        11592.0
# Bean Exports            198598.0      NaN             NaN          473.0
# Bean Imports                 NaN   4350.0         19050.0       488215.0
# Beginning Stocks         45905.0      NaN             NaN       123363.0
# Domestic Consumption      5165.0  28045.0         26090.0       509288.0
# Ending Stocks            45702.0      NaN             NaN       129463.0
# Exports                 198598.0      NaN             NaN         5781.0
# Imports                      NaN  28045.0         26090.0       509577.0
# Other Production             NaN      NaN             NaN            NaN
# Production              203560.0      NaN             NaN        11592.0
# Roast & Ground Exports       NaN      NaN             NaN         5301.0
# Roast & Ground Imports       NaN   6145.0          4045.0         2890.0
# Robusta Production      176632.0      NaN             NaN            NaN
# Rst,Ground Dom. Consum    5165.0  10495.0         23095.0       494192.0
# Soluble Dom. Cons.           NaN  17550.0          2995.0        15096.0
# Soluble Exports              NaN      NaN             NaN            7.0
# Soluble Imports              NaN  17550.0          2995.0        13145.0
# Total Distribution      249465.0  28045.0         26090.0       644532.0
# Total Supply            249465.0  28045.0         26090.0       644532.0
#
# Country_Name            Venezuela   Vietnam   Yemen  Yemen (Sanaa)  Zambia  \
# Attribute_Description
# Arabica Production        55668.0   16706.0  3301.0         1911.0  1233.0
# Bean Exports              11324.0  512143.0   935.0         1584.0  1162.0
# Bean Imports               6463.0    5486.0     NaN            NaN     NaN
# Beginning Stocks          13853.0   41103.0     NaN            NaN    12.0
# Domestic Consumption      50619.0   43332.0  2276.0          310.0   181.0
# Ending Stocks             13660.0   44158.0     NaN            NaN    12.0
# Exports                   12016.0  539885.0  1025.0         1601.0  1162.0
# Imports                    6774.0    9738.0     NaN            NaN   110.0
# Other Production              NaN     294.0     NaN            NaN     NaN
# Production                55668.0  576534.0  3301.0         1911.0  1233.0
# Roast & Ground Exports      647.0    5607.0    90.0           17.0     NaN
# Roast & Ground Imports      139.0    2207.0     NaN            NaN   110.0
# Robusta Production            NaN  559534.0     NaN            NaN     NaN
# Rst,Ground Dom. Consum    50352.0   38205.0  2276.0          310.0   181.0
# Soluble Dom. Cons.          267.0    5127.0     NaN            NaN     NaN
# Soluble Exports              45.0   22135.0     NaN            NaN     NaN
# Soluble Imports             172.0    2045.0     NaN            NaN     NaN
# Total Distribution        76295.0  627375.0  3301.0         1911.0  1355.0
# Total Supply              76295.0  627375.0  3301.0         1911.0  1355.0
#
# Country_Name            Zimbabwe
# Attribute_Description
# Arabica Production        4228.0
# Bean Exports              3949.0
# Bean Imports                 NaN
# Beginning Stocks          1207.0
# Domestic Consumption       334.0
# Ending Stocks             1206.0
# Exports                   3949.0
# Imports                     54.0
# Other Production             NaN
# Production                4228.0
# Roast & Ground Exports       NaN
# Roast & Ground Imports      54.0
# Robusta Production           NaN
# Rst,Ground Dom. Consum     334.0
# Soluble Dom. Cons.           NaN
# Soluble Exports              NaN
# Soluble Imports              NaN
# Total Distribution        5489.0
# Total Supply              5489.0
#
# [19 rows x 84 columns]

# %%
attribute_values_country.plot.barh(stacked=True,width=0.75)
plt.xlabel('Value')
plt.legend(bbox_to_anchor=(1.5,-0.1), ncols=5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#imports

plt.subplots(figsize=(10,15))
exports_country = attribute_values_country.loc['Imports'].sort_values(ascending=True).dropna()
plt.title('Imports by Country')
plt.xlabel('Value')
exports_country.plot.barh()
# Out:
# <AxesSubplot: title={'center': 'Imports by Country'}, ylabel='Country_Name'>

# %%
#exports

plt.subplots(figsize=(10,15))
exports_country = attribute_values_country.loc['Exports'].sort_values(ascending=True).dropna()
plt.title('Exports by Country')
plt.xlabel('Value')
exports_country.plot.barh()
# Out:
# <AxesSubplot: title={'center': 'Exports by Country'}, ylabel='Country_Name'>

# %%
#Production

plt.subplots(figsize=(10,15))
exports_country = attribute_values_country.loc['Production'].sort_values(ascending=True).dropna()
plt.title('Production by Country')
plt.xlabel('Value')
exports_country.plot.barh()
# Out:
# <AxesSubplot: title={'center': 'Production by Country'}, ylabel='Country_Name'>

# %%
#total Distribution

plt.subplots(figsize=(10,15))
exports_country = attribute_values_country.loc['Total Distribution'].sort_values(ascending=True).dropna()
plt.title('Total Distribution by Country')
plt.xlabel('Value')
exports_country.plot.barh()
# Out:
# <AxesSubplot: title={'center': 'Total Distribution by Country'}, ylabel='Country_Name'>

# %%
#Domestic Consumption

plt.subplots(figsize=(10,15))
exports_country = attribute_values_country.loc['Domestic Consumption'].sort_values(ascending=True).dropna()
plt.title('Domestic Consumption')
plt.xlabel('Value')
exports_country.plot.barh()
# Out:
# <AxesSubplot: title={'center': 'Domestic Consumption'}, ylabel='Country_Name'>
